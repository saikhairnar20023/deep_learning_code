# %% [markdown]
# <a href="https://colab.research.google.com/github/saikhairnar20023/deep_learning_code/blob/main/neural_network_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
x = np.array([-1.0,1.0,3.0,5.0,7.0,9.0],dtype=float)
y = np.array([-5.0,0.0,5.0,10.0,15.0,20.0],dtype=float)

# %%
model = tf.keras.Sequential(keras.layers.Dense(units=1,input_shape=[1]))

# %%
model.compile(optimizer='sgd',loss='mean_squared_error')

# %%
model.fit(x,y,epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 8ms/step - loss: 4.0535e-08
# Epoch 2/500
# 1/1 [==============================] - 0s 10ms/step - loss: 3.9841e-08
# Epoch 3/500
# 1/1 [==============================] - 0s 12ms/step - loss: 3.9113e-08
# Epoch 4/500
# 1/1 [==============================] - 0s 8ms/step - loss: 3.8478e-08
# Epoch 5/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.7843e-08
# Epoch 6/500
# 1/1 [==============================] - 0s 10ms/step - loss: 3.7311e-08
# Epoch 7/500
# 1/1 [==============================] - 0s 8ms/step - loss: 3.6707e-08
# Epoch 8/500
# 1/1 [==============================] - 0s 20ms/step - loss: 3.6139e-08
# Epoch 9/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.5492e-08
# Epoch 10/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.4928e-08
# Epoch 11/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.4292e-08
# Epoch 12/500
# ...

# %%
print(model.predict([10.0]))
# Out:
# 1/1 [==============================] - 0s 26ms/step
# [[22.499855]]
